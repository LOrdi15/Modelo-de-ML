# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
canciones = pd.read_csv('spotify-2023.csv',encoding='latin1')
canciones.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %% [markdown]
# 1. Verifica la cantidad de datos que tienes tanto para las variables (columnas) como para los renglones.
# 2. Identifica los tipos de variables con que estás trabajando.

# %%
canciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# 3. Analiza las variables para saber que representa cada una, en que rangos se encuentran y cuales son sus cuartiles.

# %%
canciones.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# Basándose en la media, mediana y desviación estándar de las variables, ¿Qué conclusiones puedes tener de los datos?
#
# Podemos observar principalmente los promedios de las canciones.
# Los puntos importantes que podemos considerar de los promedios son:
#
# * La cantidad media de artistas por cancion es 1.
# * Junio es el promedio de cuando se lanzan las canciones
# * A mediados de mes es el promedio cuando se lanzan las canciones
# * Las canciones estan mas en playlists de spotify que en Apple Music pero en apple estan mas en las charts que en las de spotify
# * El promedio de las canciones son movidas rondando los 120 bpm lo cual mantiene una energia y bailabilidad del 65% juntando ambas
# * Ultimamente las canciones no son muy acusticas al igual que carencen de instrumentalidad casi por su totalidad

# %%
canciones.hist(figsize=(15, 15))
plt.tight_layout()
plt.show()

# %%
canciones.boxplot(figsize=(15, 10))
plt.xticks(rotation=90)
plt.show()

# %%
columnas_numericas = canciones.select_dtypes(include=['float64', 'int64'])
matriz_corr = columnas_numericas.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Mapa de Calor de Correlación')
plt.show()

# %% [markdown]
# Redacta al menos tres conclusiones a las que hayas llegado a partir de tu análisis.
#
# En los histogramas, se pueden apreciar como estan distribuidos los datos, podemos decir que se aprecia la moda de los datos.
# A esto me refiero a que por ejemplo la mayoria de las canciones solo las interpretan 1 persona, la mayoria de la data son canciones lanzadas a partir del 2020, la mayoria de las canciones se lanzan a principios y a fin de mes empezando los primeros dias de los meses o a mediados.
#
# Una de las comparativas mas notables es que por lo menos 700 canciones oscilan entre las 10 mil playlists de spotify mientras que en apple music oscilan entre 200. Podemos decir que son mas famosas en spotify entre los playlists de los usuarios
# pero las canciones se encuentran en mas charts de apple que de lo que es spotify ya que oscilan entre 150 y las de spotu entre 30 sin mencionar que deezer 15
#
# Tambien podemos concluir que las canciones estan acompañados tres datos. La bailabilidad, la positividad y la energia de las canciones. Ya que los datos oscilan entre el 60% de estas variables
